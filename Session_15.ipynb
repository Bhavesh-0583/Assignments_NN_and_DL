# %% [markdown]
# # Session 15 — Practice Notebook
#
# A lightly customized version of the original exercises.

# %% [markdown]
# ## Part 1 — Experiment

# %% [markdown]
# ## Final Review
#
# Run each section in order and try changing one value or model setting to see how the result changes.
